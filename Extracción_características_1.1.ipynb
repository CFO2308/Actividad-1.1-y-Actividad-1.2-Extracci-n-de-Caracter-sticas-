# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
#Cargar archivo csv desde equipo 
df = pd.read_csv('Belize_limpio.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3357 entries, 0 to 3356
# Data columns (total 50 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            3357 non-null   int64
#  1   source                                        3357 non-null   object
#  2   name                                          3357 non-null   object
#  3   neighborhood_overview                         1800 non-null   object
#  4   host_id                                       3357 non-null   int64
#  5   host_name                                     3357 non-null   object
#  6   host_since                                    3357 non-null   object
#  7   host_location                                 2556 non-null   object
#  8   host_response_time                            2935 non-null   object
#  9   host_response_rate                            2935 non-null   object
#  10  host_acceptance_rate                          3006 non-null   object
#  11  host_is_superhost                             3276 non-null   object
#  12  host_listings_count                           3357 non-null   int64
#  13  host_total_listings_count                     3357 non-null   int64
#  14  host_identity_verified                        3357 non-null   object
#  15  neighbourhood                                 1801 non-null   object
#  16  neighbourhood_cleansed                        3357 non-null   object
#  17  neighbourhood_group_cleansed                  3357 non-null   object
#  18  latitude                                      3357 non-null   float64
#  19  longitude                                     3357 non-null   float64
#  20  property_type                                 3357 non-null   object
#  21  room_type                                     3357 non-null   object
#  22  accommodates                                  3357 non-null   int64
#  23  bathrooms                                     2812 non-null   float64
#  24  bedrooms                                      3291 non-null   float64
#  25  beds                                          2812 non-null   float64
#  26  amenities                                     3357 non-null   object
#  27  price                                         2813 non-null   object
#  28  minimum_nights                                3357 non-null   int64
#  29  maximum_nights                                3357 non-null   int64
#  30  minimum_minimum_nights                        3357 non-null   int64
#  31  has_availability                              3149 non-null   object
#  32  availability_30                               3357 non-null   int64
#  33  availability_60                               3357 non-null   int64
#  34  availability_90                               3357 non-null   int64
#  35  availability_365                              3357 non-null   int64
#  36  number_of_reviews                             3357 non-null   int64
#  37  number_of_reviews_ltm                         3357 non-null   int64
#  38  number_of_reviews_l30d                        3357 non-null   int64
#  39  first_review                                  2664 non-null   object
#  40  last_review                                   2664 non-null   object
#  41  review_scores_rating                          2664 non-null   float64
#  42  review_scores_accuracy                        2664 non-null   float64
#  43  review_scores_value                           2664 non-null   float64
#  44  instant_bookable                              3357 non-null   object
#  45  calculated_host_listings_count                3357 non-null   int64
#  46  calculated_host_listings_count_entire_homes   3357 non-null   int64
#  47  calculated_host_listings_count_private_rooms  3357 non-null   int64
#  48  calculated_host_listings_count_shared_rooms   3357 non-null   int64
#  49  reviews_per_month                             2664 non-null   float64
# dtypes: float64(9), int64(19), object(22)
# memory usage: 1.3+ MB

# %%
df.head()
# Out:
#        id       source                                               name  \
# 0   36690  city scrape                                   Mo's Cozy Cabana
# 1  120115  city scrape    Seaside Villas 4 2nd Flr - Pool, Beach, Jacuzzi
# 2  120116  city scrape                           Valarosa - Sweet cottage
# 3  152512  city scrape  Toucan-kit, ac, wifi, bike, tropical gardens, ...
# 4  152922  city scrape                     rent a private room in a house
#
#                                neighborhood_overview  host_id       host_name  \
# 0  The cabana is just a moments walk to 'The Spli...   157752         Monique
# 1  Right on the beach, this building is in a prim...   604999           Bobbi
# 2  Valarosa is on Avenida Chechem in a popular re...   604999           Bobbi
# 3  LOVE this area of Placencia; quiet, day & nigh...   733857  Jacqueline Ann
# 4  Quiet neighbourhood, close to shopping centre,...   735525        Jennifer
#
#   host_since        host_location  host_response_time host_response_rate  ...  \
# 0   03/07/10               Belize      within an hour               100%  ...
# 1   19/05/11  Belize City, Belize      within an hour               100%  ...
# 2   19/05/11  Belize City, Belize      within an hour               100%  ...
# 3   23/06/11    Placencia, Belize      within an hour               100%  ...
# 4   23/06/11     Belmopan, Belize  a few days or more                 0%  ...
#
#   last_review review_scores_rating  review_scores_accuracy  \
# 0    20/12/24                 4.82                    4.83
# 1    05/11/24                 4.81                    4.91
# 2    30/07/24                 4.59                    4.72
# 3    25/03/24                 4.86                    4.89
# 4    13/04/24                 4.58                    4.92
#
#    review_scores_value instant_bookable calculated_host_listings_count  \
# 0                 4.88                f                              4
# 1                 4.71                t                             19
# 2                 4.58                t                             19
# 3                 4.86                t                              5
# 4                 4.83                f                              1
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           4
# 1                                          19
# 2                                          19
# 3                                           4
# 4                                           0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            1
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               2.58
# 1                                            0               0.73
# 2                                            0               0.79
# 3                                            0               0.46
# 4                                            0               0.11
#
# [5 rows x 50 columns]

# %% [markdown]
# ## Variables Categóricas

# %%
df["host_response_rate"] = df["host_response_rate"].str.rstrip('%').astype(float)
data = df["host_response_rate"].dropna()
bins = int(1 + 3.20 * np.log10(len(data)))

plt.hist(data, bins=bins, edgecolor='black')
plt.title("host_response_rate")
plt.xlabel("host_response_rate")
plt.ylabel("Frecuencia")
plt.show()

# %%
df["host_acceptance_rate"] = df["host_acceptance_rate"].str.rstrip('%').astype(float)
data = df["host_acceptance_rate"].dropna()
bins = int(1 + 3.20 * np.log10(len(data)))

plt.hist(data, bins=bins, edgecolor='black')
plt.title("host_acceptance_rate")
plt.xlabel("host_acceptance_rate")
plt.ylabel("Frecuencia")
plt.show()

# %%
data = df["has_availability"].dropna()
bins = int(1 + 3.20 * np.log10(len(data)))

plt.hist(data, bins=bins, edgecolor='black')
plt.title("has_availability")
plt.xlabel("has_availability")
plt.ylabel("Frecuencia")
plt.show()

# %%
data = df["host_identity_verified"].dropna()
bins = int(1 + 3.20 * np.log10(len(data)))

plt.hist(data, bins=bins, edgecolor='black')
plt.title("host_identity_verified")
plt.xlabel("host_identity_verified")
plt.ylabel("Frecuencia")
plt.show()

# %%
data = df["instant_bookable"].dropna()
bins = int(1 + 3.20 * np.log10(len(data)))

plt.hist(data, bins=bins, edgecolor='black')
plt.title("instant_bookable")
plt.xlabel("instant_bookable")
plt.ylabel("Frecuencia")
plt.show()

# %%
data = df["neighbourhood_cleansed"].dropna()
bins = int(1 + 3.322 * np.log10(len(data)))

plt.hist(data, bins=bins, edgecolor='black')
plt.title("neighbourhood_cleansed")
plt.xlabel("neighbourhood_cleansed")
plt.ylabel("Frecuencia")
plt.show()

# %%
data = df["property_type"].dropna()
bins = int(1 + 3.2 * np.log10(len(data)))

plt.hist(data, bins=bins, edgecolor='black')
plt.title("property_type")
plt.xlabel("property_type")
plt.ylabel("Frecuencia")
plt.show()

# %%
data = df["room_type"].dropna()
bins = int(1 + 3.2 * np.log10(len(data)))

plt.hist(data, bins=bins, edgecolor='black')
plt.title("room_type")
plt.xlabel("room_type")
plt.ylabel("Frecuencia")
plt.show()

# %%
data = df["host_is_superhost"].dropna()
bins = int(1 + 3.2 * np.log10(len(data)))

plt.hist(data, bins=bins, edgecolor='black')
plt.title("host_is_superhost")
plt.xlabel("host_is_superhost")
plt.ylabel("Frecuencia")
plt.show()

# %%
data = df["host_response_time"].dropna()
bins = int(1 + 3.2 * np.log10(len(data)))

plt.hist(data, bins=bins, edgecolor='black')
plt.title("host_response_time")
plt.xlabel("host_response_time")
plt.ylabel("Frecuencia")
plt.show()

# %% [markdown]
# ## Variables Numéricas

# %%
data = df["host_total_listings_count"].dropna()
bins = int(1 + 3.2 * np.log10(len(data)))

plt.hist(data, bins=bins, edgecolor='black')
plt.title("host_total_listings_count")
plt.xlabel("host_total_listings_count")
plt.ylabel("Frecuencia")
plt.show()

# %%
data = df["accommodates"].dropna()
bins = int(1 + 3.15 * np.log10(len(data)))

plt.hist(data, bins=bins, edgecolor='black')
plt.title("accommodates")
plt.xlabel("accommodates")
plt.ylabel("Frecuencia")
plt.show()

# %%
data = df["bathrooms"].dropna()
bins = int(1 + 3.2 * np.log10(len(data)))

plt.hist(data, bins=bins, edgecolor='black')
plt.title("bathrooms")
plt.xlabel("bathrooms")
plt.ylabel("Frecuencia")
plt.show()

# %%
data = df["beds"].dropna()
bins = int(1 + 3.322 * np.log10(len(data)))

plt.hist(data, bins=bins, edgecolor='black')
plt.title("beds")
plt.xlabel("beds")
plt.ylabel("Frecuencia")
plt.show()

# %%
df["price"] = df["price"].replace('[\$,]', '', regex=True).astype(float)
data = df["price"].dropna()
bins = int(1 + 3.322 * np.log10(len(data)))

plt.hist(data, bins=bins, edgecolor='black')
plt.title("price")
plt.xlabel("price")
plt.ylabel("Frecuencia")
plt.show()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# <>:1: SyntaxWarning: invalid escape sequence '\$'
# /var/folders/cr/23ck8vtn1kd8mbhg9wssxh440000gn/T/ipykernel_8104/3477886802.py:1: SyntaxWarning: invalid escape sequence '\$'
#   df["price"] = df["price"].replace('[\$,]', '', regex=True).astype(float)

# %%
data = df["maximum_nights"].dropna()
bins = int(1 + 3.322 * np.log10(len(data)))

plt.hist(data, bins=bins, edgecolor='black')
plt.title("maximum_nights")
plt.xlabel("maximum_nights")
plt.ylabel("Frecuencia")
plt.show()

# %%
data = df["availability_365"].dropna()
bins = int(1 + 3.322 * np.log10(len(data)))

plt.hist(data, bins=bins, edgecolor='black')
plt.title("availability_365")
plt.xlabel("availability_365")
plt.ylabel("Frecuencia")
plt.show()

# %%
data = df["number_of_reviews"].dropna()
bins = int(1 + 3.322 * np.log10(len(data)))

plt.hist(data, bins=bins, edgecolor='black')
plt.title("number_of_reviews")
plt.xlabel("number_of_reviews")
plt.ylabel("Frecuencia")
plt.show()

# %%
data = df["review_scores_value"].dropna()
bins = int(1 + 3.20 * np.log10(len(data)))

plt.hist(data, bins=bins, edgecolor='black')
plt.title("review_scores_value")
plt.xlabel("review_scores_value")
plt.ylabel("Frecuencia")
plt.show()

# %%
data = df["reviews_per_month"].dropna()
bins = int(1 + 3.20 * np.log10(len(data)))

plt.hist(data, bins=bins, edgecolor='black')
plt.title("reviews_per_month")
plt.xlabel("reviews_per_month")
plt.ylabel("Frecuencia")
plt.show()
